# %%
from huggingface_hub import snapshot_download

# Download images (lightened SEM-like PNGs)
snapshot_download(
    repo_id="DhruvGarodia/capstone_project_cmu_2026",
    repo_type="dataset",
    allow_patterns="synthetic/lightened/lightened_pfibs_500/*",
    local_dir="data/lightened_pfibs_500/",
    local_dir_use_symlinks=False
)

# Download masks (binary ground truth PNGs)
snapshot_download(
    repo_id="DhruvGarodia/capstone_project_cmu_2026",
    repo_type="dataset",
    allow_patterns="synthetic/mask/synthetic_pfibs_500/*",
    local_dir="data/synthetic_pfibs_500/",
    local_dir_use_symlinks=False
)
# Out:
# ...
# Fetching 1651 files:   0%|          | 0/1651 [00:00<?, ?it/s]
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/datasets/DhruvGarodia/capstone_project_cmu_2026/resolve/709c65448506ee960827bbae0ffd49991d50209c/synthetic/mask/synthetic_pfibs_500/synthetic_7/slice_0145.png
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/datasets/DhruvGarodia/capstone_project_cmu_2026/resolve/709c65448506ee960827bbae0ffd49991d50209c/synthetic/mask/synthetic_pfibs_500/synthetic_7/slice_0146.png
# Retrying in 1s [Retry 1/5].
# HTTP Error 429 thrown while requesting HEAD https://huggingface.co/datasets/DhruvGarodia/capstone_project_cmu_2026/resolve/709c65448506ee960827bbae0ffd49991d50209c/synthetic/mask/synthetic_pfibs_500/synthetic_7/slice_0144.png
# Retrying in 1s [Retry 1/5].
# ...
